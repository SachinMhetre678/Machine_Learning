# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinMhetre678/Machine_Learning/blob/main/Pandas/Seriess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
help(pd.Series)

# %%
myindex = ["USA","Canda","Mexico"]

# %%
mydata = [1776,1867,1821]

# %%
myser = pd.Series(data = mydata,index=myindex)

# %%
myser
# Out:
# USA       1776
# Canda     1867
# Mexico    1821
# dtype: int64

# %%
myser[0]
# Out:
# 1776

# %%
myser["USA"]
# Out:
# 1776

# %%
ages = {'Sam':5,'Frank':10,'Spike':7}

# %%
pd.Series(ages)
# Out:
# Sam       5
# Frank    10
# Spike     7
# dtype: int64
