# %% [markdown]
# <a href="https://colab.research.google.com/github/SachinMhetre678/Machine_Learning/blob/main/Logistic_Regression/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hearing_test.csv')

# %%
df.head()
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %%
df.test_result.dtypes
# Out:
# dtype('int64')

# %%
df.describe()
# Out:
#                age  physical_score  test_result
# count  5000.000000     5000.000000  5000.000000
# mean     51.609000       32.760260     0.600000
# std      11.287001        8.169802     0.489947
# min      18.000000       -0.000000     0.000000
# 25%      43.000000       26.700000     0.000000
# 50%      51.000000       35.300000     1.000000
# 75%      60.000000       38.900000     1.000000
# max      90.000000       50.000000     1.000000

# %%
df['test_result'].value_counts()
# Out:
# 1    3000
# 0    2000
# Name: test_result, dtype: int64

# %%
sns.countplot(data = df,x='test_result')
# Out:
# <Axes: xlabel='test_result', ylabel='count'>

# %%
plt.figure(dpi=150)
sns.boxplot(x='test_result',y='age',data=df)
# Out:
# <Axes: xlabel='test_result', ylabel='age'>

# %%
plt.figure(dpi=150)
sns.boxplot(x='test_result',y='physical_score',data=df)
# Out:
# <Axes: xlabel='test_result', ylabel='physical_score'>

# %%
plt.figure(dpi=150)
sns.scatterplot(x='age',y='physical_score',
                data=df,hue='test_result',alpha=0.5)
# Out:
# <Axes: xlabel='age', ylabel='physical_score'>

# %%
sns.pairplot(df,hue='test_result')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='physical_score',y='test_result',data=df)
# Out:
# <Axes: xlabel='physical_score', ylabel='test_result'>

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(df['age'],df['physical_score'], df['test_result'],c=df['test_result'])

# %%
df.head()
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %%
x = df.drop('test_result',axis=1)

# %%
y = df['test_result']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.1,random_state=101)

# %%
scaler = StandardScaler()

# %%
scaled_x_train = scaler.fit_transform(x_train)

# %%
scaled_x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
log_model.fit(scaled_x_train,y_train)
# Out:
# LogisticRegression()

# %%
log_model.coef_
# Out:
# array([[-0.94953524,  3.45991194]])

# %%
y_pred = log_model.predict_proba(scaled_x_test)

# %%
y_pred

# %%
df.head()
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
y_pred = log_model.predict(scaled_x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.93

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[172,  21],
#        [ 14, 293]])

# %%
# !pip install scikit-learn

# %%
pip install --upgrade scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 38.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Create a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(cm)
disp.plot()

# %%
from sklearn.metrics import plot_confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-104-ebfa5cfc2bb8> in <cell line: 1>()
# ----> 1 from sklearn.metrics import plot_confusion_matrix
#
# ImportError: cannot import name 'plot_confusion_matrix' from 'sklearn.metrics' (/usr/local/lib/python3.10/dist-packages/sklearn/metrics/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
plot_confusion_matrix(log_model,scaled_x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-a8449d8cd055> in <cell line: 1>()
# ----> 1 plot_confusion_matrix(log_model,scaled_x_test,y_test)
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/plotting/plot_confusion_matrix.py in plot_confusion_matrix(conf_mat, hide_spines, hide_ticks, figsize, cmap, colorbar, show_absolute, show_normed, norm_colormap, class_names, figure, axis, fontcolor_threshold)
#      99         )
#     100
# --> 101     total_samples = conf_mat.sum(axis=1)[:, np.newaxis]
#     102     normed_conf_mat = conf_mat.astype("float") / total_samples
#     103
#
# AttributeError: 'LogisticRegression' object has no attribute 'sum'
